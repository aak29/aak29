# %% [markdown]
# <a href="https://colab.research.google.com/github/aak29/aak29/blob/main/Example_Stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the packages
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web

# %%
#Pick a style:
style.use('ggplot')

# %%
start = dt.datetime(2022,1,1)
end = dt.datetime(2022,12,31)

# %%
#Create a dataframe
df_tsla = web.DataReader('TSLA', 'stooq', start, end)
df_ford= web.DataReader('F', 'stooq', start, end)
df_toyota= web.DataReader('TM', 'stooq', start, end)

# %%
#flip dates

df_tsla2=df_tsla
df_tsla2 = df_tsla2.iloc[::-1]

df_ford2=df_ford
df_ford2=df_ford2.iloc[::-1]

df_toyota2=df_toyota
df_toyota2=df_toyota2.iloc[::-1]

# %%
df_tsla2
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2022-01-03  382.58  400.36  378.68  399.93  104686047
# 2022-01-04  396.52  402.67  374.35  383.20  100248258
# 2022-01-05  382.22  390.11  360.34  362.71   80119797
# 2022-01-06  359.00  362.67  340.17  354.90   90336474
# 2022-01-07  360.12  360.31  336.67  342.32   84164748
# ...            ...     ...     ...     ...        ...
# 2022-11-29  184.99  186.38  178.75  180.83   83357111
# 2022-11-30  182.43  194.76  180.63  194.70  109186404
# 2022-12-01  197.08  198.92  191.80  194.70   80046213
# 2022-12-02  191.78  196.25  191.11  194.86   73645922
# 2022-12-05  189.44  191.27  180.55  182.45   93122667
#
# [233 rows x 5 columns]

# %%
df_ford2
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2022-01-03  20.81  21.41  20.61  21.30  1.13e+08
# 2022-01-04  22.04  24.03  21.94  23.79  3.18e+08
# 2022-01-05  23.54  24.41  22.97  23.15  2.59e+08
# 2022-01-06  23.57  24.09  22.86  23.94  1.58e+08
# 2022-01-07  24.14  24.38  23.52  23.92  1.30e+08
# ...           ...    ...    ...    ...       ...
# 2022-11-29  13.85  13.90  13.71  13.75  2.84e+07
# 2022-11-30  13.78  13.95  13.45  13.90  6.15e+07
# 2022-12-01  14.09  14.36  14.00  14.08  4.53e+07
# 2022-12-02  13.84  13.97  13.75  13.86  4.24e+07
# 2022-12-05  13.75  13.77  13.37  13.38  3.97e+07
#
# [233 rows x 5 columns]

# %%
df_toyota2
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2022-01-03  184.83  185.47  183.20  184.31  3.57e+05
# 2022-01-04  191.03  199.29  190.28  197.08  1.07e+06
# 2022-01-05  197.68  199.20  194.76  194.86  5.62e+05
# 2022-01-06  198.50  198.67  194.10  197.63  4.27e+05
# 2022-01-07  198.55  199.85  196.61  198.31  3.75e+05
# ...            ...     ...     ...     ...       ...
# 2022-11-29  145.26  146.18  144.87  145.40  1.70e+05
# 2022-11-30  145.44  147.87  144.85  147.69  1.72e+05
# 2022-12-01  147.22  148.24  146.58  147.66  2.00e+05
# 2022-12-02  145.56  146.61  144.99  146.53  1.65e+05
# 2022-12-05  144.76  144.80  142.65  143.19  2.24e+05
#
# [233 rows x 5 columns]

# %%
df_tsla2.to_csv('tsla.csv')
df_ford2.to_csv('ford.csv')
df_toyota2.to_csv('toyota.csv')

# %%
#Reduce decimal places for easier viewing
pd.set_option("display.precision", 2)

# %%
df_tsla = pd.read_csv('tsla.csv', parse_dates=True, index_col=0)
df_ford = pd.read_csv('ford.csv', parse_dates=True, index_col=0)
df_toyota = pd.read_csv('toyota.csv', parse_dates=True, index_col=0)

# %%
df_tsla['100ma'] = df_tsla['Close'].rolling(window=100, min_periods=0).mean()
df_tsla
# Out:
#               Open    High     Low   Close     Volume   100ma
# Date
# 2022-01-03  382.58  400.36  378.68  399.93  104686047  399.93
# 2022-01-04  396.52  402.67  374.35  383.20  100248258  391.56
# 2022-01-05  382.22  390.11  360.34  362.71   80119797  381.94
# 2022-01-06  359.00  362.67  340.17  354.90   90336474  375.18
# 2022-01-07  360.12  360.31  336.67  342.32   84164748  368.61
# ...            ...     ...     ...     ...        ...     ...
# 2022-11-29  184.99  186.38  178.75  180.83   83357111  252.07
# 2022-11-30  182.43  194.76  180.63  194.70  109186404  251.68
# 2022-12-01  197.08  198.92  191.80  194.70   80046213  251.29
# 2022-12-02  191.78  196.25  191.11  194.86   73645922  250.87
# 2022-12-05  189.44  191.27  180.55  182.45   93122667  250.31
#
# [233 rows x 6 columns]

# %%
df_ford['100ma'] = df_ford['Close'].rolling(window=100, min_periods=0).mean()
df_ford
# Out:
#              Open   High    Low  Close    Volume  100ma
# Date
# 2022-01-03  20.81  21.41  20.61  21.30  1.13e+08  21.30
# 2022-01-04  22.04  24.03  21.94  23.79  3.18e+08  22.55
# 2022-01-05  23.54  24.41  22.97  23.15  2.59e+08  22.75
# 2022-01-06  23.57  24.09  22.86  23.94  1.58e+08  23.04
# 2022-01-07  24.14  24.38  23.52  23.92  1.30e+08  23.22
# ...           ...    ...    ...    ...       ...    ...
# 2022-11-29  13.85  13.90  13.71  13.75  2.84e+07  13.69
# 2022-11-30  13.78  13.95  13.45  13.90  6.15e+07  13.72
# 2022-12-01  14.09  14.36  14.00  14.08  4.53e+07  13.74
# 2022-12-02  13.84  13.97  13.75  13.86  4.24e+07  13.77
# 2022-12-05  13.75  13.77  13.37  13.38  3.97e+07  13.79
#
# [233 rows x 6 columns]

# %%
df_toyota['100ma'] = df_toyota['Close'].rolling(window=100, min_periods=0).mean()
df_toyota
# Out:
#               Open    High     Low   Close    Volume   100ma
# Date
# 2022-01-03  184.83  185.47  183.20  184.31  3.57e+05  184.31
# 2022-01-04  191.03  199.29  190.28  197.08  1.07e+06  190.70
# 2022-01-05  197.68  199.20  194.76  194.86  5.62e+05  192.08
# 2022-01-06  198.50  198.67  194.10  197.63  4.27e+05  193.47
# 2022-01-07  198.55  199.85  196.61  198.31  3.75e+05  194.44
# ...            ...     ...     ...     ...       ...     ...
# 2022-11-29  145.26  146.18  144.87  145.40  1.70e+05  146.08
# 2022-11-30  145.44  147.87  144.85  147.69  1.72e+05  146.01
# 2022-12-01  147.22  148.24  146.58  147.66  2.00e+05  145.93
# 2022-12-02  145.56  146.61  144.99  146.53  1.65e+05  145.84
# 2022-12-05  144.76  144.80  142.65  143.19  2.24e+05  145.74
#
# [233 rows x 6 columns]

# %%
#The size for our chart:
plt.figure(figsize = (12,6))
#Plotting Adj Close and SMA lines:
ax1 = plt.subplot2grid((8,1),(0,0),rowspan=5,colspan=1)
ax2 = plt.subplot2grid((8,1),(6,0),rowspan=3,colspan=1, sharex=ax1)

ax1.plot(df_tsla.index,df_tsla['Close'], 'r',label='Adjusted Close')
ax1.plot(df_tsla.index,df_tsla['100ma'], 'g', label= "100 Moving Average")
plt.xlabel('Date')
#ax1.set_xlabel('Date')
ax1.set_ylabel('Adjusted closing price ($)')
ax1.set_title('Adjusted Close and 100 day Moving Average for TSLA')
ax1.legend()

ax2.bar(df_tsla.index,df_tsla['Volume'], label = "Volume", color='b')
ax2.legend()

plt.show()

# %%
#The size for our chart:
plt.figure(figsize = (12,6))
#Plotting Adj Close and SMA lines:
ax1 = plt.subplot2grid((8,1),(0,0),rowspan=5,colspan=1)
ax2 = plt.subplot2grid((8,1),(6,0),rowspan=3,colspan=1, sharex=ax1)

ax1.plot(df_ford.index,df_ford['Close'], 'r',label='Adjusted Close')
ax1.plot(df_ford.index,df_ford['100ma'], 'g', label= "100 Moving Average")
plt.xlabel('Date')
#ax1.set_xlabel('Date')
ax1.set_ylabel('Adjusted closing price ($)')
ax1.set_title('Adjusted Close and 100 day Moving Average for Ford Motors')
ax1.legend()

ax2.bar(df_ford.index,df_ford['Volume'], label = "Volume", color='b')
ax2.legend()

plt.show()

# %%
#The size for our chart:
plt.figure(figsize = (12,6))
#Plotting Adj Close and SMA lines:
ax1 = plt.subplot2grid((8,1),(0,0),rowspan=5,colspan=1)
ax2 = plt.subplot2grid((8,1),(6,0),rowspan=3,colspan=1, sharex=ax1)

ax1.plot(df_toyota.index,df_toyota['Close'], 'r',label='Adjusted Close')
ax1.plot(df_toyota.index,df_toyota['100ma'], 'g', label= "100 Moving Average")
plt.xlabel('Date')
#ax1.set_xlabel('Date')
ax1.set_ylabel('Adjusted closing price ($)')
ax1.set_title('Adjusted Close and 100 day Moving Average for Toyota Motors')
ax1.legend()

ax2.bar(df_toyota.index,df_toyota['Volume'], label = "Volume", color='b')
ax2.legend()

plt.show()

# %%
df_live = web.DataReader('LIVE', 'stooq', start, end)
df_live
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2022-12-05  25.00  25.00  24.98  24.98    1252
# 2022-12-02  24.50  25.00  24.50  25.00    1444
# 2022-12-01  25.70  25.70  24.52  24.52    1704
# 2022-11-30  24.70  25.55  24.70  25.20    1990
# 2022-11-29  25.00  25.00  24.80  24.80    1729
# ...           ...    ...    ...    ...     ...
# 2022-01-07  29.26  30.50  29.22  29.22    5412
# 2022-01-06  30.30  30.30  29.27  29.35    5235
# 2022-01-05  30.00  31.15  29.00  30.92    8984
# 2022-01-04  30.30  30.66  28.93  29.80   17097
# 2022-01-03  31.63  31.95  29.42  30.46   20778
#
# [229 rows x 5 columns]

# %%
! pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.1 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
import yfinance as yf

# %%
ticker_stock= yf.Ticker("MSFT")
ticker_stock.info['longBusinessSummary']
# Out:
# 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company operates in three segments: Productivity and Business Processes, Intelligent Cloud, and More Personal Computing. The Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, Microsoft Viva, and Skype for Business; Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. The Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related Client Access Licenses; GitHub that provides a collaboration platform and code hosting service for developers; Nuance provides healthcare and enterprise AI solutions; and Azure, a cloud platform. It also offers enterprise support, Microsoft consulting, and nuance professional services to assist customers in developing,
# ...

# %% [markdown]
# # Five year mission

# %%
start = dt.datetime(2018,1,1)
end = dt.datetime(2022,12,31)

# %%
#Create a dataframe
df_tsla5= web.DataReader('TSLA', 'stooq', start, end)
df_ford5= web.DataReader('F', 'stooq', start, end)
df_toyota5= web.DataReader('TM', 'stooq', start, end)

# %%
#flip dates

df_tsla2=df_tsla5
df_tsla2 = df_tsla2.iloc[::-1]

df_ford2=df_ford5
df_ford2=df_ford2.iloc[::-1]

df_toyota2=df_toyota5
df_toyota2=df_toyota2.iloc[::-1]

# %%
df_tsla2 # five years of tesla
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2018-01-02   20.80   21.47   20.73   21.37   65188275
# 2018-01-03   21.40   21.68   21.04   21.15   66893295
# 2018-01-04   20.86   21.24   20.38   20.97  149194260
# 2018-01-05   21.11   21.15   20.80   21.11   68838660
# 2018-01-08   21.07   22.47   21.03   22.43  147555480
# ...            ...     ...     ...     ...        ...
# 2022-11-29  184.99  186.38  178.75  180.83   83357111
# 2022-11-30  182.43  194.76  180.63  194.70  109186404
# 2022-12-01  197.08  198.92  191.80  194.70   80046213
# 2022-12-02  191.78  196.25  191.11  194.86   73645922
# 2022-12-05  189.44  191.27  180.55  182.45   93122667
#
# [1241 rows x 5 columns]
